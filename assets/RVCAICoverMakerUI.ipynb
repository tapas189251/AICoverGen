# %% [markdown]
# <a href="https://colab.research.google.com/github/tapas189251/AICoverGen/blob/main/assets/RVCAICoverMakerUI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **RVC AI Cover Maker UI**
# - Created by [Shirou](https://github.com/ShiromiyaG)
# - Maintained by [Not Eddy (Spanish Mod)](http://discord.com/users/274566299349155851) in [AI HUB](https://discord.gg/aihub) community
# - Improved the Start UI Cell with other Tunnel types by [Nick088](https://linktr.ee/Nick088)
# <br>This colab uses the following projects:
# - [Music Source Separation Universal Training Code](https://github.com/ZFTurbo/Music-Source-Separation-Training) by [ZFTurbo](https://github.com/ZFTurbo)
# - [Applio](https://github.com/IAHispano/Applio) by [IAHispano](https://github.com/IAHispano)

# %%
#@title ## **Install**

# !sudo apt update
# !sudo apt install python3.10
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.10 1
# !sudo update-alternatives --set python3 /usr/bin/python3.10
# !curl -sS https://bootstrap.pypa.io/get-pip.py | python3
import sys
sys.path.append('/usr/local/lib/python3.10/dist-packages')

import os
import codecs
from IPython.display import clear_output
print("Installing requirements")
repo = codecs.decode("uggcf://tvguho.pbz/Rqqlpenpx864/EIP-NV-Pbire-Znxre-HV.tvg", "rot_13")
# !git clone $repo main_program  &> /dev/null
# %cd main_program
# !pip install uv pyngrok -q
# !uv pip install --no-deps -r requirements.txt -q
# !uv pip install torch==2.3.1 torchvision==0.18.1 torchaudio==2.3.1 --upgrade --index-url https://download.pytorch.org/whl/cu121 -q
# !uv pip install numpy==1.23.5 -q
# !python programs/applio_code/rvc/lib/tools/prerequisites_download.py
clear_output()
print("Requirements installed!")
# Out:
# Requirements installed!

# %%
#@title ## **Start UI**

#@markdown The type of tunnel you wanna use for seeing the public link, so that if one of them is down, you can use the other one.
Tunnel = "Gradio" #@param ["Gradio", "Ngrok", "LocalTunnel", "Horizon"]

#@markdown Also when using Ngrok, LocalTunnel or Horizon, you need to wait for the Local URL to appear, and only after that click on the Public URL which is above.

#@markdown Use the following option **only if you chose Ngrok** as the Tunnel:

#@markdown You can get the Ngrok Authtoken here: https://dashboard.ngrok.com/tunnels/authtokens/new.

ngrok_authtoken = "" #@param {type:"string"}

# @markdown You can optinally change the Ngrok Tunnel Region to one nearer to you for lower latency

ngrok_region = "us - United States (Ohio)" # @param ["au - Australia (Sydney)","eu - Europe (Frankfurt)", "ap - Asia/Pacific (Singapore)", "us - United States (Ohio)", "jp - Japan (Tokyo)", "in - India (Mumbai)","sa - South America (Sao Paulo)"]



#@markdown Use the following option **only if you chose Horizon** as the Tunnel:

#@markdown You can get the Horizon ID here: https://hrzn.run/dashboard/ , login, on the 2nd step, it shows an `hrzn login YOUR_ID`, you need to copy that id.

horizon_id = "" #@param {type:"string"}


import codecs
from IPython.display import clear_output

RUNTIME = codecs.decode("znva.cl", "rot_13")

if Tunnel == "Gradio":
    share_flag = "--share"
elif Tunnel == "Ngrok":
  share_flag = ""
  from pyngrok import conf, ngrok
  NgrokConfig = conf.PyngrokConfig()
  NgrokConfig.auth_token = ngrok_authtoken
  NgrokConfig.region = ngrok_region[0:2]
  conf.set_default(NgrokConfig)
  main_tunnel = ngrok.connect(7755)
  print("Ngrok Tunnel Public URL:", main_tunnel.public_url)
elif Tunnel == "LocalTunnel":
  share_flag = ""
  # install
  # !npm install -g localtunnel
  import time
  import urllib
  # run localtunnel
  with open('url.txt', 'w') as file:
        file.write('')

  get_ipython().system_raw('lt --port 7755 >> url.txt 2>&1 &')

  time.sleep(4)

  endpoint_ip = urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n")

  with open('url.txt', 'r') as file:
      tunnel_url = file.read()
      tunnel_url = tunnel_url.replace("your url is: ", "")

  clear_output()
  print(f"LocalTunnel Tunnel Public URL: \033[0m\033[93m{tunnel_url}\033[0m", end="\033[0m")

  print(f'LocalTunnel Password: {endpoint_ip}')
elif Tunnel == "Horizon":
  share_flag = ""
  # install
  # !npm install -g @hrzn/cli
  import time
  # login
  # !hrzn login $horizon_id
  # run horizon
  with open('url.txt', 'w') as file:
        file.write('')

  get_ipython().system_raw('hrzn tunnel http://localhost:7755 >> url.txt 2>&1 &')

  time.sleep(4)

  with open('url.txt', 'r') as file:
      tunnel_url = file.read()
      tunnel_url = !grep -oE "https://[a-zA-Z0-9.-]+\.hrzn\.run" url.txt
      tunnel_url = tunnel_url[0]

  clear_output()

  print(f"Horizon Tunnel Public URL: \033[0m\033[93m{tunnel_url}\033[0m")

# kills previously running processes
# !fuser -k 7755/tcp

command = f"python {RUNTIME} {share_flag}"
# !{command}
# Out:
# /usr/local/lib/python3.10/dist-packages/librosa/core/intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:309: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:309: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# theme_schema%400.0.1.json: 13.5kB [00:00, 47.8MB/s]
# Running on local URL:  http://127.0.0.1:7755
# IMPORTANT: You are using gradio version 4.36.0, however version 4.44.1 is available, please upgrade.
# --------
# Running on public URL: https://11944cffd6507bb7ba.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/queueing.py", line 532, in process_events
#     response = await route_utils.call_process_api(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/route_utils.py", line 276, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1923, in process_api
#     result = await self.call_function(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1509, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 2177, in run_sync_in_worker_thread
#     return await future
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 859, in run
#     result = context.run(func, *args)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 832, in wrapper
#     response = f(*args, **kwargs)
#   File "/content/main_program/tabs/download_model.py", line 18, in save_drop_model
#     raise gr.Error(
# gradio.exceptions.Error: 'The file you dropped is not a valid model file. Please try again.'
# model.pth saved in /content/main_program/logs/model
# model.index saved in /content/main_program/logs/model
# Number of GPUs available: 1
# 100% 871M/871M [00:08<00:00, 106MB/s]
# File 'model.ckpt' downloaded successfully
# 100% 1.68k/1.68k [00:00<00:00, 7.10MB/s]
# File 'config.yaml' downloaded successfully
# Separating vocals
# CUDA is available, use --force_cpu to disable it.
# Using device:  cuda:0
# GPU Compute Capability below 8.0, using math or mem efficient attention if input tensor is on cuda
# Start from checkpoint: /content/main_program/models/mel-vocals/model.ckpt
# Instruments: ['vocals', 'other']
# Model load time: 7.12 sec
# Starting processing track:  audio_files/original_files/_Tanveer_Evan_-_Shunno_Cover.wav
# Elapsed time: 23.00 sec
# Separating Backing vocals
# 100% 871M/871M [00:03<00:00, 284MB/s]
# File 'model.ckpt' downloaded successfully
# 100% 1.60k/1.60k [00:00<00:00, 9.20MB/s]
# File 'config.yaml' downloaded successfully
# CUDA is available, use --force_cpu to disable it.
# Using device:  cuda:0
# GPU Compute Capability below 8.0, using math or mem efficient attention if input tensor is on cuda
# Start from checkpoint: /content/main_program/models/mel-kara/model.ckpt
# Instruments: ['karaoke', 'other']
# Model load time: 5.66 sec
# Starting processing track:  /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/vocals/_Tanveer_Evan_-_Shunno_Cover_vocals.flac
# Elapsed time: 28.15 sec
# Removing reverb
# 28.3kiB [00:00, 51.5MiB/s]
# 100% 224M/224M [00:06<00:00, 32.2MiB/s]
# 4.38kiB [00:00, 13.8MiB/s]
# 15.4kiB [00:00, 28.8MiB/s]
# 100% 4/4 [00:01<00:00,  2.41it/s]
# 100% 21/21 [00:00<00:00, 240001.05it/s]
# 100% 21/21 [00:04<00:00,  4.93it/s]
# Removing echo
# 28.3kiB [00:00, 63.6MiB/s]
# 100% 127M/127M [00:03<00:00, 37.5MiB/s]
# 4.38kiB [00:00, 10.7MiB/s]
# 15.4kiB [00:00, 40.2MiB/s]
# 100% 4/4 [00:00<00:00,  4.03it/s]
# 100% 21/21 [00:00<00:00, 264505.66it/s]
# 100% 21/21 [00:02<00:00,  8.94it/s]
# Making RVC inference
# Converting audio '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho.flac'...
# Converting audio to FLAC format...
# Conversion completed at '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/rvc/_Tanveer_Evan_-_Shunno_Cover_rvc.flac' in 10.03 seconds.
# Merging audios
# Audios merged!
# Number of GPUs available: 1
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/queueing.py", line 532, in process_events
#     response = await route_utils.call_process_api(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/route_utils.py", line 276, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1923, in process_api
#     result = await self.call_function(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1509, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 2177, in run_sync_in_worker_thread
#     return await future
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 859, in run
#     result = context.run(func, *args)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 832, in wrapper
#     response = f(*args, **kwargs)
#   File "/content/main_program/core.py", line 344, in full_inference_program
#     first_device = devices.split()[0]
# IndexError: list index out of range
# Number of GPUs available: 1
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/queueing.py", line 532, in process_events
#     response = await route_utils.call_process_api(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/route_utils.py", line 276, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1923, in process_api
#     result = await self.call_function(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1509, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 2177, in run_sync_in_worker_thread
#     return await future
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 859, in run
#     result = context.run(func, *args)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 832, in wrapper
#     response = f(*args, **kwargs)
#   File "/content/main_program/core.py", line 344, in full_inference_program
#     first_device = devices.split()[0]
# IndexError: list index out of range
# Number of GPUs available: 1
# Separating vocals
# CUDA is available, use --force_cpu to disable it.
# Using device:  cuda:0
# GPU Compute Capability below 8.0, using math or mem efficient attention if input tensor is on cuda
# Start from checkpoint: /content/main_program/models/mel-vocals/model.ckpt
# Instruments: ['vocals', 'other']
# Model load time: 6.16 sec
# Starting processing track:  audio_files/original_files/_Tanveer_Evan_-_Shunno_Cover.wav
# Elapsed time: 15.96 sec
# Separating Backing vocals
# CUDA is available, use --force_cpu to disable it.
# Using device:  cuda:0
# GPU Compute Capability below 8.0, using math or mem efficient attention if input tensor is on cuda
# Start from checkpoint: /content/main_program/models/mel-kara/model.ckpt
# Instruments: ['karaoke', 'other']
# Model load time: 6.17 sec
# Starting processing track:  /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/vocals/_Tanveer_Evan_-_Shunno_Cover_vocals.flac
# Elapsed time: 28.31 sec
# Removing reverb
# 100% 4/4 [00:00<00:00,  4.16it/s]
# 100% 21/21 [00:00<00:00, 229376.00it/s]
# 100% 21/21 [00:03<00:00,  6.07it/s]
# Removing echo
# 100% 4/4 [00:00<00:00,  4.21it/s]
# 100% 21/21 [00:00<00:00, 212754.55it/s]
# 100% 21/21 [00:02<00:00,  9.09it/s]
# Making RVC inference
# Converting audio '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho.flac'...
# Segment 0 created!
# Segment 1 created!
# Segment 2 created!
# Segment 3 created!
# Segment 4 created!
# Segment 5 created!
# Total segments created: 6
# Split all chunks for /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho.flac successfully!
# Converting audio '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk0.wav'...
# Converting audio to FLAC format...
# Conversion completed at '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk0.flac' in 3.82 seconds.
# Converting audio '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk2.wav'...
# Converting audio to FLAC format...
# Conversion completed at '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk2.flac' in 1.96 seconds.
# Converting audio '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk5.wav'...
# Converting audio to FLAC format...
# Conversion completed at '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk5.flac' in 2.29 seconds.
# Converting audio '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk1.wav'...
# Converting audio to FLAC format...
# Conversion completed at '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk1.flac' in 1.54 seconds.
# Converting audio '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk3.wav'...
# Converting audio to FLAC format...
# Conversion completed at '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk3.flac' in 1.53 seconds.
# Converting audio '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk4.wav'...
# Converting audio to FLAC format...
# Conversion completed at '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk4.flac' in 1.82 seconds.
# Finished processing segmented audio, now merging audio...
# Processing file: /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho_timestamps.txt
# Processed chunk: /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk0.wav
# Processed chunk: /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk1.wav
# Processed chunk: /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk2.wav
# Processed chunk: /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk3.wav
# Processed chunk: /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk4.wav
# Processed chunk: /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk5.wav
# Converting audio to FLAC format...
# Conversion completed at '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/rvc/_Tanveer_Evan_-_Shunno_Cover_rvc.flac' in 26.87 seconds.
# Merging audios
# Audios merged!
# Number of GPUs available: 1
# Separating vocals
# CUDA is available, use --force_cpu to disable it.
# Using device:  cuda:0
# GPU Compute Capability below 8.0, using math or mem efficient attention if input tensor is on cuda
# Start from checkpoint: /content/main_program/models/mel-vocals/model.ckpt
# Instruments: ['vocals', 'other']
# Model load time: 6.29 sec
# Starting processing track:  audio_files/original_files/_Tanveer_Evan_-_Shunno_Cover.wav
# Elapsed time: 15.43 sec
# Separating Backing vocals
# CUDA is available, use --force_cpu to disable it.
# Using device:  cuda:0
# GPU Compute Capability below 8.0, using math or mem efficient attention if input tensor is on cuda
# Start from checkpoint: /content/main_program/models/mel-kara/model.ckpt
# Instruments: ['karaoke', 'other']
# Model load time: 6.20 sec
# Starting processing track:  /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/vocals/_Tanveer_Evan_-_Shunno_Cover_vocals.flac
# Elapsed time: 28.31 sec
# Removing reverb
# 100% 4/4 [00:00<00:00,  4.38it/s]
# 100% 21/21 [00:00<00:00, 272694.69it/s]
# 100% 21/21 [00:03<00:00,  6.03it/s]
# Removing echo
# 100% 4/4 [00:00<00:00,  4.21it/s]
# 100% 21/21 [00:00<00:00, 242645.69it/s]
# 100% 21/21 [00:02<00:00,  9.15it/s]
# Making RVC inference
# Converting audio '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho.flac'...
# Segment 0 created!
# Segment 1 created!
# Segment 2 created!
# Segment 3 created!
# Segment 4 created!
# Segment 5 created!
# Total segments created: 6
# Split all chunks for /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho.flac successfully!
# Converting audio '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk0.wav'...
# Converting audio to FLAC format...
# Conversion completed at '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk0.flac' in 2.62 seconds.
# Converting audio '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk2.wav'...
# Converting audio to FLAC format...
# Conversion completed at '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk2.flac' in 1.71 seconds.
# Converting audio '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk5.wav'...
# Converting audio to FLAC format...
# Conversion completed at '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk5.flac' in 1.42 seconds.
# Converting audio '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk1.wav'...
# Converting audio to FLAC format...
# Conversion completed at '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk1.flac' in 1.45 seconds.
# Converting audio '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk3.wav'...
# Converting audio to FLAC format...
# Conversion completed at '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk3.flac' in 1.67 seconds.
# Converting audio '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk4.wav'...
# Converting audio to FLAC format...
# Conversion completed at '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk4.flac' in 1.64 seconds.
# Finished processing segmented audio, now merging audio...
# Processing file: /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho_timestamps.txt
# Processed chunk: /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk0.wav
# Processed chunk: /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk1.wav
# Processed chunk: /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk2.wav
# Processed chunk: /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk3.wav
# Processed chunk: /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk4.wav
# Processed chunk: /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk5.wav
# Converting audio to FLAC format...
# Conversion completed at '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/rvc/_Tanveer_Evan_-_Shunno_Cover_rvc.flac' in 24.59 seconds.
# Merging audios
# Audios merged!
# Number of GPUs available: 1
# Separating vocals
# CUDA is available, use --force_cpu to disable it.
# Using device:  cuda:0
# GPU Compute Capability below 8.0, using math or mem efficient attention if input tensor is on cuda
# Start from checkpoint: /content/main_program/models/mel-vocals/model.ckpt
# Instruments: ['vocals', 'other']
# Model load time: 5.25 sec
# Starting processing track:  audio_files/original_files/_Tanveer_Evan_-_Shunno_Cover.wav
# Elapsed time: 16.45 sec
# Separating Backing vocals
# CUDA is available, use --force_cpu to disable it.
# Using device:  cuda:0
# GPU Compute Capability below 8.0, using math or mem efficient attention if input tensor is on cuda
# Start from checkpoint: /content/main_program/models/mel-kara/model.ckpt
# Instruments: ['karaoke', 'other']
# Model load time: 5.53 sec
# Starting processing track:  /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/vocals/_Tanveer_Evan_-_Shunno_Cover_vocals.flac
# Elapsed time: 29.31 sec
# Removing reverb
# 100% 4/4 [00:00<00:00,  4.24it/s]
# 100% 21/21 [00:00<00:00, 256047.63it/s]
# 100% 21/21 [00:03<00:00,  6.06it/s]
# Removing echo
# 100% 4/4 [00:00<00:00,  4.20it/s]
# 100% 21/21 [00:00<00:00, 256047.63it/s]
# 100% 21/21 [00:02<00:00,  9.07it/s]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/queueing.py", line 532, in process_events
#     response = await route_utils.call_process_api(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/route_utils.py", line 276, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1923, in process_api
#     result = await self.call_function(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1509, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 2177, in run_sync_in_worker_thread
#     return await future
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 859, in run
#     result = context.run(func, *args)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 832, in wrapper
#     response = f(*args, **kwargs)
#   File "/content/main_program/core.py", line 683, in full_inference_program
#     separator.separate(input_file)
#   File "/usr/local/lib/python3.10/dist-packages/audio_separator/separator/separator.py", line 705, in separate
#     output_files = self.model_instance.separate(audio_file_path)
#   File "/usr/local/lib/python3.10/dist-packages/audio_separator/separator/architectures/vr_separator.py", line 192, in separate
#     self.primary_source = self.spec_to_wav(y_spec).T
#   File "/usr/local/lib/python3.10/dist-packages/audio_separator/separator/architectures/vr_separator.py", line 346, in spec_to_wav
#     wav = spec_utils.cmb_spectrogram_to_wave(spec, self.model_params, is_v51_model=self.is_vr_51_model)
#   File "/usr/local/lib/python3.10/dist-packages/audio_separator/separator/uvr_lib_v5/spec_utils.py", line 388, in cmb_spectrogram_to_wave
#     wave = librosa.resample(wave2, orig_sr=bp["sr"], target_sr=sr, res_type=wav_resolution)
#   File "/usr/local/lib/python3.10/dist-packages/librosa/core/audio.py", line 627, in resample
#     util.valid_audio(y, mono=False)
#   File "/usr/local/lib/python3.10/dist-packages/librosa/util/utils.py", line 314, in valid_audio
#     raise ParameterError("Audio buffer is not finite everywhere")
# librosa.util.exceptions.ParameterError: Audio buffer is not finite everywhere
# Number of GPUs available: 1
# Vocals already separated
# Backing vocals already separated
# Reverb already removed
# Removing echo
# 100% 4/4 [00:00<00:00,  4.17it/s]
# 100% 21/21 [00:00<00:00, 259824.14it/s]
# 100% 21/21 [00:02<00:00,  9.20it/s]
# Making RVC inference
# Converting audio '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho.flac'...
# Segment 0 created!
# Segment 1 created!
# Segment 2 created!
# Segment 3 created!
# Segment 4 created!
# Segment 5 created!
# Total segments created: 6
# Split all chunks for /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho.flac successfully!
# Converting audio '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk0.wav'...
# Converting audio to FLAC format...
# Conversion completed at '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk0.flac' in 2.84 seconds.
# Converting audio '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk2.wav'...
# Converting audio to FLAC format...
# Conversion completed at '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk2.flac' in 1.76 seconds.
# Converting audio '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk5.wav'...
# Converting audio to FLAC format...
# Conversion completed at '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk5.flac' in 1.44 seconds.
# Converting audio '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk1.wav'...
# Converting audio to FLAC format...
# Conversion completed at '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk1.flac' in 1.32 seconds.
# Converting audio '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk3.wav'...
# Converting audio to FLAC format...
# Conversion completed at '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk3.flac' in 1.26 seconds.
# Converting audio '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk4.wav'...
# Converting audio to FLAC format...
# Conversion completed at '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk4.flac' in 1.60 seconds.
# Finished processing segmented audio, now merging audio...
# Processing file: /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho_timestamps.txt
# Processed chunk: /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk0.wav
# Processed chunk: /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk1.wav
# Processed chunk: /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk2.wav
# Processed chunk: /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk3.wav
# Processed chunk: /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk4.wav
# Processed chunk: /content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/deecho/_Tanveer_Evan_-_Shunno_Cover_noecho/chunk5.wav
# Converting audio to FLAC format...
# Conversion completed at '/content/main_program/audio_files/_Tanveer_Evan_-_Shunno_Cover/rvc/_Tanveer_Evan_-_Shunno_Cover_rvc.flac' in 24.90 seconds.
# Merging audios
# Audios merged!
